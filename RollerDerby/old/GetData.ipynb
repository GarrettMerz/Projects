# %%
import requests
import pandas as pd
import numpy as np
import trueskill
from bs4 import BeautifulSoup
from itertools import product
from urllib.request import urlopen
import networkx as nx
from networkx.drawing.nx_agraph import to_agraph 
import matplotlib.pyplot as plt
import pylab
import sys
import nbimporter
import Webscraper as wsc

np.set_printoptions(threshold=sys.maxsize)
edgelist_test = "Data/STGraphs/3637STGraph.edgelist"

# %%
def getWeightedAdjMatrixFromEdgeList(edgelist):
    G = nx.read_weighted_edgelist(edgelist)
    mat = nx.to_numpy_matrix(G)
    return mat

# %%
def getAdjMatrixFromEdgeList(edgelist):
    G = nx.read_weighted_edgelist(edgelist)
    mat = 1*(nx.to_numpy_matrix(G) != False)
    return mat

# %%
print(getWeightedAdjMatrixFromEdgeList(edgelist_test))
# Out:
# [[ 0.00000000e+00  1.02260374e+01  2.69117647e+00  1.84257703e+01
#    2.82378466e+01  1.35304902e+01  2.56805699e+01  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.02260374e+01  0.00000000e+00  8.39796652e+00  1.68253099e+01
#    1.04175306e+01  1.46761530e+01  1.40611632e+01  1.89551860e+01
# ...

# %%
def MakeTrainTestFromEdgeList(edgelist):
    G = nx.read_weighted_edgelist(edgelist)
